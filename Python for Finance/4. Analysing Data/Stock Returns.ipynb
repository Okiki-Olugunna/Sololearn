# %%
import yfinance as yf
import pandas as pd
import numpy as np
import numpy_financial as npf
import matplotlib.pyplot as plt

# %%
#TSLA stock prices over the last year 
data = yf.Ticker("TSLA")
price = data.history(period = "1y")

# %%
x = price['Close'].pct_change()
print(x)
# Out:
# Date
# 2021-01-08         NaN
# 2021-01-11   -0.078214
# 2021-01-12    0.047153
# 2021-01-13    0.005851
# 2021-01-14   -0.011013
#                 ...
# 2022-01-03    0.135317
# 2022-01-04   -0.041833
# 2022-01-05   -0.053471
# 2022-01-06   -0.021523
# 2022-01-07   -0.035447
# Name: Close, Length: 253, dtype: float64

# %%
x.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
x.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# returns if invested $1

returns = (x + 1).cumprod()
returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
