# %%
import yfinance as yf
import pandas as pd
import numpy as np
import numpy_financial as npf
import matplotlib.pyplot as plt

# %%
data = yf.download("AAPL MSFT TSLA", start="2021-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
x = data['Close'].pct_change()
print(x)
# Out:
#                 AAPL      MSFT      TSLA
# Date
# 2021-01-04       NaN       NaN       NaN
# 2021-01-05  0.012364  0.000965  0.007317
# 2021-01-06 -0.033662 -0.025929  0.028390
# 2021-01-07  0.034123  0.028457  0.079447
# 2021-01-08  0.008631  0.006093  0.078403
# ...              ...       ...       ...
# 2022-01-03  0.025004 -0.004668  0.135317
# 2022-01-04 -0.012692 -0.017147 -0.041833
# 2022-01-05 -0.026600 -0.038388 -0.053471
# 2022-01-06 -0.016693 -0.007902 -0.021523
# 2022-01-07  0.000988  0.000510 -0.035447
#
# [257 rows x 3 columns]

# %%
print(x.describe())
# Out:
#              AAPL        MSFT        TSLA
# count  256.000000  256.000000  256.000000
# mean     0.001241    0.001522    0.001955
# std      0.015838    0.013391    0.035555
# min     -0.041674   -0.038388   -0.119903
# 25%     -0.007707   -0.005595   -0.017784
# 50%      0.001322    0.000372    0.001637
# 75%      0.012409    0.010244    0.019089
# max      0.053851    0.042114    0.196412

# %%
data['Close'].plot(title="Daily Prices")
x.plot(title="Percentage Change")
# Out:
# <AxesSubplot:title={'center':'Percentage Change'}, xlabel='Date'>

# %%
(x+1).cumprod().plot(title="Value of a $1 Investment")
# Out:
# <AxesSubplot:title={'center':'Value of a $1 Investment'}, xlabel='Date'>
