# %%
import statsmodels.api as sm
import yfinance as yf
import pandas as pd
import numpy as np
import numpy_financial as npf
import matplotlib.pyplot as plt

# %%
data = yf.download("FB AMZN AAPL NFLX GOOG", start="2020-01-01")
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
x = data['Close'].pct_change()
corr = x.corr()
print(corr)
# Out:
#           AAPL      AMZN        FB      GOOG      NFLX
# AAPL  1.000000  0.671899  0.695295  0.697971  0.515895
# AMZN  0.671899  1.000000  0.632104  0.652080  0.610127
# FB    0.695295  0.632104  1.000000  0.736895  0.523017
# GOOG  0.697971  0.652080  0.736895  1.000000  0.508242
# NFLX  0.515895  0.610127  0.523017  0.508242  1.000000

# %%
sm.graphics.plot_corr(corr, xnames=list(x.columns))
