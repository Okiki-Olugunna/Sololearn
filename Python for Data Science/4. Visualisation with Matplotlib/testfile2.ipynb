# %%
import pandas as pd
import matplotlib.pyplot as plt

s = pd.Series([18, 42, 9, 32, 81, 64, 3]) 

s.plot(kind='bar') 
plt.savefig('plot.png')

# %%
s.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
s.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
s.plot(kind='hist', bins=8, color='red')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
s.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
s.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
s.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
s.plot() #line chart by default
# Out:
# <AxesSubplot:>

# %%
s.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
plt.title("TestFile")
# Out:
# Text(0.5, 1.0, 'TestFile')

# %%
s.plot()
# Out:
# <AxesSubplot:>
